# %% [markdown]
# # **Theory Questions**

# %% [markdown]
# 1. **What is a random variable in probability theory?**
# - In probability theory, a random variable is a mathematical concept used to quantify the outcomes of a random experiment. It is a variable that can take on different values, each associated with a certain probability, depending on the outcome of the experiment. Essentially, it links the outcomes of random processes to numerical values, making it easier to perform statistical and probabilistic analyses.

# %% [markdown]
# 2. **What are the types of random variables?**
# - There are basically two types of random variables:
#   - Descrete Random Variable
#   - Continuous Random Variable

# %% [markdown]
# 3. **What is the difference between discrete and continuous distributions?**
# - Discrete Random Variable:
#   - Takes on a finite or countable number of distinct values.
#   - Example: The number of heads in 10 coin tosses, where the possible values could be ( {0, 1, 2, ..., 10} ).
# - Continuous Random Variable:
#   - Can take on an infinite number of values within a certain range.
#   - Example: The time it takes to run a marathon, which could be any value within a given interval (e.g., 2.5 hours to 5 hours).

# %% [markdown]
# 4. **What are probability distribution functions (PDF)?**
# - A Probability Distribution Function (PDF) is a mathematical function that describes the likelihood of a random variable taking on specific values. The concept varies slightly depending on whether the random variable is discrete or continuous
# - There are basically two types of PDF:
#   - Probability Mass Function(PMF)(Descrete Outcomes).
#   - Probability Density Function(PDF)(Continuous outcomes).

# %% [markdown]
# 5. **How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?**
# - Probability Distribution Function (PDF):
#   - The PDF (or Probability Density Function, for continuous variables) represents the relative likelihood of a random variable taking on a specific value (for discrete variables) or a value within an infinitesimally small range (for continuous variables).
#   - Example: In a normal distribution, the bell-shaped curve is the PDF, showing the relative likelihood of data points around the mean.
# - Cumulative Distribution Function (CDF):
#   - The CDF represents the probability that a random variable takes on a value less than or equal to a specific value, ( x ). It accumulates the probabilities from the beginning (minimum value) up to ( x ).
#   - Example: In a normal distribution, the CDF at ( x = 1 ) gives the probability that the random variable is less than or equal to 1.

# %% [markdown]
# 6. **What is a discrete uniform distribution?**
# - A discrete uniform distribution is a type of probability distribution where each value in a finite set of outcomes has an equal probability of occurring. It is a simple and intuitive distribution commonly used in scenarios where all outcomes are equally likely.
# - Example: Rolling a dice, Choosing a card.

# %% [markdown]
# 7. **What are the key properties of a Bernoulli distribution?**
# - The Bernoulli distribution is one of the simplest probability distributions in statistics. It models a random experiment with only two possible outcomes, often labeled as "success" (1) and "failure" (0).
# - Key Properties:
#   - Two outcomes.
#   - single trial.
#   - It doesnot remember the past.
#   - mean is eqal to the probability of success.

# %% [markdown]
# 8. **What is the binomial distribution, and how is it used in probability?**
# - The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials of a binary experiment. Each trial has only two possible outcomes: "success" or "failure." The binomial distribution is widely used in probability and statistics to analyze scenarios with repeated independent experiments.
# - The binomial distribution is used in various fields, including:
#   - Determining the probability that a certain number of products are defective in a sample.
#   - Analyzing the success rate of a new treatment in trials.
#   - Estimating the likelihood of a basketball player making a specific number of free throws out of a certain number of attempts.
#   - Predicting the probability of survey responses based on voter preferences.

# %% [markdown]
# 9. **What is the Poisson distribution and where is it applied?**
# - The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time, space, or other measures, under the assumption that these events happen independently and at a constant average rate. It is particularly useful for situations where the occurrences are rare and random.
# - The Poisson distribution is widely used in scenarios involving rare or random events, including:
#   - Modeling the number of customers arriving at a store or call center in a given time period.
#   - Counting the number of cars passing through a specific checkpoint in a certain duration.
#   - Estimating the number of patients arriving at an emergency room during a fixed interval.
#   - Modeling occurrences such as earthquakes in a geographical area or meteor strikes on the Earth.
#   - Predicting the number of calls received by a call center within a certain time period.
# - and so on.

# %% [markdown]
# 10. **What is a continuous uniform distribution?**
# - The continuous uniform distribution is a probability distribution that describes random variables with an equal likelihood of occurring anywhere within a specified range. In other words, it is used to model events where every outcome in a continuous interval has the same probability.

# %% [markdown]
# 11. **What are the characteristics of a normal distribution?**
# - The normal distribution, also referred to as the Gaussian distribution, is one of the most widely used and fundamental concepts in statistics. It describes how values of a random variable are distributed in a bell-shaped curve.
# - Characteristics:
#   - The normal distribution is perfectly symmetrical about the mean. The left and right halves of the curve are mirror images.
#   - In a normal distribution, the mean, median, and mode are equal and all located at the center of the curve.
#   - The curve is highest at the mean and tapers off symmetrically as you move away from the center.
#   - The tails of the normal distribution extend infinitely in both directions but approach the horizontal axis without ever touching it.

# %% [markdown]
# 12. **What is the standard normal distribution, and why is it important?**
# - The standard normal distribution is a specific type of normal distribution that has been standardized. It serves as the foundation for much of statistical theory and is widely used in data analysis.
# - It is important because:
#   - Standardizing normal distributions into the standard normal form reduces the complexity of calculations.
#   - The standard normal distribution allows the use of z-scores, which indicate how many standard deviations a value is away from the mean. Z-scores are essential for comparing values across different datasets.
#   - Tables for the standard normal distribution (e.g., z-tables) provide probabilities for specific z-scores, making it easy to compute probabilities and critical values.
#   - Used in hypothesis testing and confidence intervals. For example, it forms the basis for t-tests, z-tests, and many other statistical methods.

# %% [markdown]
# 13. **What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
# - The Central Limit Theorem (CLT) is one of the most important principles in statistics. It describes how the distribution of sample means becomes approximately normal (bell-shaped) as the sample size increases, regardless of the original distribution of the population, provided certain conditions are met.
# - It is critical in statistics because:
#   - The CLT allows statisticians to make inferences about population parameters using sample data, even when the population distribution is unknown.
#   - Many statistical tests (e.g., z-tests, t-tests) and methods for constructing confidence intervals rely on the assumption of normality in the sampling distribution, which is guaranteed by the CLT for large samples.
#   - It ensures that complex or non-normal distributions of population data can be analyzed using the simpler tools of the normal distribution.

# %% [markdown]
# 14. **How does the Central Limit Theorem relate to the normal distribution?**
# - he Central Limit Theorem (CLT) connects the normal distribution to random sampling. It states that the sampling distribution of the sample mean becomes approximately normal as the sample size increases, regardless of the population’s original distribution. This approximation is centered around the population.
# - This principle justifies the widespread use of the normal distribution in statistics, enabling statistical tests, confidence intervals, and predictions even when underlying data is not normally distributed. The CLT is critical for making reliable inferences based on sample data, bridging real-world distributions and statistical modeling.

# %% [markdown]
# 15. **What is the application of Z statistics in hypothesis testing?**
# - Z-tests are used to assess whether the sample  differs significantly from a population mean. This is common in evaluating claims or predictions about population characteristics.
# - Z-tests can be applied to test hypotheses about proportions. For example, determining whether the proportion of defective items in a production batch differs from an expected rate.
# - Z-statistics are used to calculate confidence intervals for the population mean or proportion to estimate the range within which the true population parameter lies, with a specified level of confidence.
# - Z-tests can also compare two independent samples, such as testing whether the means of two groups (e.g., treatment vs. control) are significantly different.

# %% [markdown]
# 16. **How do you calculate a Z-score, and what does it represent?**
# - We can calculate the Z-score by using the formula:
#   - z = (x-mean)/Standard deviation
# - Z-score represents:
#   - A Z-score tells you where a data point lies relative to the mean:
#     - ( Z = 0 ): The data point equals the mean.
#     - ( Z > 0 ): The data point is above the mean.
#     - ( Z < 0 ): The data point is below the mean.
#   - The absolute value of the Z-score shows how far the data point is from the mean, measured in standard deviations.
#   - In a standard normal distribution, the Z-score can be used to find the probability or area under the curve corresponding to the data point.

# %% [markdown]
# 17. **What are point estimates and interval estimates in statistics?**
# - Point Estimates:
#   - A point estimate provides a single, specific value as the best guess for a population parameter.
#   - It is derived directly from the sample data and serves as a concise representation of the parameter.
# - Interval Estimates:
#   - An interval estimate provides a range of values within which the population parameter is likely to lie, along with a specified level of confidence (e.g., 95%, 99%).
#   - This range is called a confidence interval and reflects the uncertainty in the estimation process.

# %% [markdown]
# 18. **What is the significance of confidence intervals in statistical analysis?**
# - Confidence intervals incorporate variability in sample data and reflect the inherent uncertainty in estimating population parameters. Unlike point estimates, they provide a range rather than a single value, acknowledging that the true parameter might fall anywhere within this range.
# - Confidence intervals are used in hypothesis testing to assess whether a parameter falls within a specific range.
# - Confidence intervals allow researchers to compare results across studies by examining overlapping intervals. If intervals for two groups do not overlap, it suggests significant differences.
# - By providing a range, confidence intervals offer a more transparent way of reporting results, preventing overconfidence in a single value derived from sample data.

# %% [markdown]
# 19. **What is the relationship between a Z-score and a confidence interval?**
# - The Z-score determines the width of the confidence interval by defining how far (in standard deviations) the range extends from the mean.
# - Higher confidence levels require larger Z-scores, resulting in wider intervals.
# - As the Z-score increases (e.g., from 1.96 to 2.576), the confidence interval becomes wider, reflecting higher confidence but lower precision.
# - The Z-score is derived from the standard normal distribution, which is used to compute the probability that a statistic lies within a specified range.

# %% [markdown]
# 20. **How are Z-scores used to compare different distributions?**
# - Z-scores are a statistical tool used to standardize and compare values across different datasets or distributions. They measure how many standard deviations a data point is from the mean, enabling the comparison of data regardless of scales or units. By transforming data into the standard normal distribution, Z-scores allow for:
#   - Comparing datasets with different means and standard deviations.
#   - Assessing relative positions of data points.
#   - Identifying outliers (Z-scores beyond ( 3 ) are often considered extreme).

# %% [markdown]
# 21. **What are the assumptions for applying the Central Limit Theorem?**
# - The Central Limit Theorem (CLT) works under certain assumptions:
#   - Observations must be independent.
#   - Samples should be chosen randomly.
#   - Sample size should be sufficiently large.
#   - The population should have finite mean and variance.
#   - All samples must come from the same distribution.

# %% [markdown]
# 22. **What is the concept of expected value in a probability distribution?**
# - It represents the average value of repeatation of experiment in the long run.
# - The expected value is the weighted average of all possible outcomes in a probability distribution, where the weights are their respective probabilities. It represents the long-term average of a random variable if the experiment is repeated infinitely.

# %% [markdown]
# 23. **How does a probability distribution relate to the expected outcome of a random variable?**
# - A probability distribution defines the possible outcomes of a random variable and their associated probabilities. The expected value, derived from this distribution, is the long-term average or "center" of the outcomes. It's calculated as the weighted average of all possible values, with weights determined by their probabilities. This relationship helps predict the typical behavior of a random variable over repeated trials.

# %% [markdown]
# # **Practical Questions**

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value.

# %%
import random
random_variable = random.randint(0,100)
print(random_variable)
# Out:
# 56

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

a = 1
b = 7

x = np.arange(a,b)

pmf = [1/(b-a)]*len(x)

sns.barplot(x = x, y = pmf, palette='Spectral', edgecolor = 'black', hue = x, legend = False)
plt.xlabel('Values')
plt.ylabel('Probability')
plt.title('PMF of Descrete Uniform Distribution')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def probability_bernoulli(p,x):
  if x not in [0,1] and not (o<=p<=1):
    raise ValueError("The value of p must be between 0 and 1 and x must be 0 or 1")
  if x == 1:
    return p
  elif x == 0:
    return 1-p
p = 0.3
x = 1
pdf = probability_bernoulli(p,x)
print(pdf)
# Out:
# 0.3

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#given
n = 10
p = 0.5
sample_size = 1000 #Assume
binomial_data = np.random.binomial(n=n, p=p, size = sample_size)

sns.histplot(x=binomial_data, palette = 'flare', hue = binomial_data, legend = False)
plt.title("Binomial Distribution")
plt.xlabel("Number of Success")
plt.ylabel("Probability")
plt.grid(axis = 'y')

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import poisson

lmda = 3

x = np.arange(0,15)

pmf = poisson.pmf(x,lmda)

sns.barplot(x=x,y=pmf, palette = 'rocket', hue = x, legend = False)
plt.xlabel("Number of event")
plt.ylabel("Probability")
plt.title("Poisson Distribution")
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
a = 1
b = 10

n = b-a
x = np.arange(a,b)
probability_descrete_uni_dist = [1/n]*len(x)

cdf = np.cumsum(probability_descrete_uni_dist)

plt.step(x,cdf, color='red')
plt.xlabel("Values")
plt.ylabel("Commulative Probability")
plt.title("CDF of a Descrete Uniform Distribution")
plt.grid(axis= 'y')
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

a=1
b=15
size = 1000
uniform_data = np.random.uniform(a,b,size)

sns.histplot(x=uniform_data, palette = 'mako', hue = uniform_data, legend = False)
plt.title("Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Quantity")
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram.

# %%
mean = 50
std = 10
size = 1000

data = np.random.normal(loc=mean, scale=std, size = size)

plt.figure(figsize=(10, 6))
sns.histplot(x=data, bins=30, edgecolor='black', palette = 'light:b', hue = data, legend = False)
plt.title('Histogram of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
def calc_and_plot(dataset):
  data = np.array(dataset)
  mean = np.mean(data)
  std = np.std(data)

  z_score = (data - mean)/std

  sns.scatterplot(x=range(len(z_score)), y = z_score, palette='magma', hue = range(len(z_score)), legend = False)
  plt.title("Zscore of dataset")
  plt.xlabel("Index")
  plt.ylabel("Z-Score")
  plt.grid(axis = 'y')
  plt.show()
  return z_score
dataset = [10,12,23,23,16,22,17,18,29,11,22]
z_scores = calc_and_plot(dataset)
print("Z-Scores are: ",z_scores)
# Out:
# Z-Scores are:  [-1.48881013 -1.13661849  0.80043556  0.80043556 -0.4322352   0.62433973
#  -0.25613938 -0.08004356  1.85701049 -1.31271431  0.62433973]

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#As non - distribution means exponential distribution
data = np.random.exponential(scale = 2, size = 1000)

plt.figure(figsize=(10,6))
sns.histplot(x = data, edgecolor = 'black', palette = 'rocket', legend = False, hue = data, bins = 50)
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Original Non-Normal Distribution")
plt.grid(axis = 'y')
plt.show()

size = 30
no_of_sample = 1000
sample_mean = []
for i in range(no_of_sample):
  sample = np.random.choice(data, size = size, replace = True)
  sample_mean.append(np.mean(sample))

plt.figure(figsize=(10,6))
sns.histplot(x = sample_mean, edgecolor = 'black', palette = 'crest', legend = False, hue = sample_mean, bins = 50)
plt.xlabel("Sample mean")
plt.ylabel("Density")
plt.title("CLT of Non-Normal Distribution")
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# **Question Number 11 to 14 isnot available on the assignment pdf**

# %% [markdown]
# 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

mean = 50
std = 10
size = 10000

data = np.random.normal(loc=mean, scale = std, size = size)

plt.figure(figsize=(10,6))
sns.histplot(x=data, bins=50, edgecolor='black', palette='magma', hue = data, legend=False, kde = True)
plt.title("Original Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(axis = 'y')
plt.show()

clt_ss = 30
clt_no_sample = 1000
sample_mean = []
for i in range(clt_no_sample):
  sample = np.random.choice(data, size = clt_ss, replace = True)
  sample_mean.append(np.mean(sample))

plt.figure(figsize=(10,6))
sns.histplot(x=sample_mean, bins=50, edgecolor='black', palette='viridis', hue = sample_mean, legend=False, kde = True)
plt.title("CLT of  Normal Distribution")
plt.xlabel("Sample mean")
plt.ylabel("Density")
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std =1).

# %%
def cal_and_plot():
  x = np.linspace(-4, 4, 1000)
  mean = 0
  std_dev = 1
  pdf = (1 / (np.sqrt(2 * np.pi) * std_dev)) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)
  plt.figure(figsize=(10, 6))
  sns.relplot(x=x, y=pdf, kind='line', label='Standard Normal Distribution (μ=0, σ=1)')
  plt.fill_between(x, pdf, color='red')
  plt.title('Standard Normal Distribution')
  plt.xlabel('Value')
  plt.ylabel('Probability Density')
  plt.grid(axis='y')
  plt.show()

cal_and_plot()

# %% [markdown]
# 17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

trial = 10
probability = 0.5
size = 10

random_var = np.random.binomial(n=trial, p=probability, size = size)

print(f"Generated Random Variable:{random_var}")

outcomes = np.arange(0,trial+1)

probability = binom.pmf(outcomes, trial, probability)

for outcome, prob in zip(outcomes, probability):
  print(f"p({outcome}) = {prob:4f}")
# Out:
# Generated Random Variable:[6 6 5 5 2 6 2 6 5 4]
# p(0) = 0.000977
# p(1) = 0.009766
# p(2) = 0.043945
# p(3) = 0.117188
# p(4) = 0.205078
# p(5) = 0.246094
# p(6) = 0.205078
# p(7) = 0.117187
# p(8) = 0.043945
# p(9) = 0.009766
# p(10) = 0.000977

# %% [markdown]
# 18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution.

# %%
import numpy as np
from scipy.stats import norm

dataset = [10, 15, 14, 12, 18, 20, 17, 16]
data_point = 14

data = np.array(dataset)
mean = np.mean(data)
std_dev = np.std(data)
z_score = (data_point - mean) / std_dev

print(f"Z-Score of the data pont{data_point}: {z_score:4f}")

probability = norm.cdf(z_score)
print(f"Probability that a value in the standard normal distribution is <= Z-score: {probability:.4f}")
# Out:
# Z-Score of the data pont14: -0.412393
# Probability that a value in the standard normal distribution is <= Z-score: 0.3400

# %% [markdown]
# 19. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
from scipy.stats import norm
import numpy as np

population_mean = 170
sample_mean = 172
sample_std = 8
n = 50
alpha = 0.05
alternative='two-sided'

z_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(n))
print(f"Z-Statistic: {z_stat:.4f}")

if alternative == 'two-sided':
        p_value = 2 * (1 - norm.cdf(abs(z_stat)))
elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_stat)
elif alternative == 'less':
        p_value = norm.cdf(z_stat)
else:
        raise ValueError("Invalid alternative. Use 'two-sided', 'greater', or 'less'.")

print(f"P-Value: {p_value:.4f}")


if p_value < alpha:
        print("Reject the null hypothesis (H₀).")
else:
        print("Fail to reject the null hypothesis (H₀).")
# Out:
# Z-Statistic: 1.7678
# P-Value: 0.0771
# Fail to reject the null hypothesis (H₀).

# %% [markdown]
# 20. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy.stats import norm

data = [10, 12, 23, 18, 20, 25, 19, 21, 17, 15]
confidence=0.95
data = np.array(data)

mean = np.mean(data)
std_dev = np.std(data, ddof=1)

n = len(data)
z_value = norm.ppf(1 - (1 - confidence) / 2)
margin_of_error = z_value * (std_dev / np.sqrt(n))
lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Confidence Interval ({confidence * 100}%): [{lower_bound:.4f}, {upper_bound:.4f}]")
# Out:
# Confidence Interval (95.0%): [15.0929, 20.9071]

# %% [markdown]
# 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy.stats import norm

mean = 50
std = 10
size = 1000
data = np.random.normal(loc = mean, scale = std, size=size)

confidence=0.95
mean = np.mean(data)
std_dev = np.std(data, ddof=1)

n = len(data)
z_value = norm.ppf(1 - (1 - confidence) / 2)
margin_of_error = z_value * (std_dev / np.sqrt(n))
lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Confidence Interval ({confidence * 100}%): [{lower_bound:.4f}, {upper_bound:.4f}]")
# Out:
# Confidence Interval (95.0%): [49.3943, 50.6488]

# %% [markdown]
# 22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

mean = 50
std = 10
x = np.linspace(mean-4*std, mean+4*std, 1000)

pdf = norm.pdf(x, loc = mean, scale=std)

plt.figure(figsize=(10,6))
sns.relplot(x=x, y=pdf, kind='line', color="violet", label=f"Normal Distribution having mean:{mean} and st. deviation:{std}")
plt.fill_between(x,pdf,color='darkblue')
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
from scipy.stats import poisson

lamb_da = 3
k = 4

cdf = poisson.cdf(k,mu=lamb_da)

print(f"Interpretation: There is a {cdf:.2%} probability that the random variable X takes a value of {k} or less")
# Out:
# Interpretation: There is a 81.53% probability that the random variable X takes a value of 4 or less

# %% [markdown]
# 24. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
a = 0
b = 10
size = 1000

data = np.random.uniform(low=a, high=b, size=size)
mean = np.mean(data)

theorical_expected_value = (a+b)/2

print(f"Approximate Expected value: {mean}")
print(f"Theotrical Expected value: {theorical_expected_value}")
# Out:
# Approximate Expected value: 5.129091944832478
# Theotrical Expected value: 5.0

# %% [markdown]
# 25. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
dataset1 = [10, 12, 14, 16, 18, 20, 22, 24]
dataset2 = [15, 15, 15, 16, 15, 15, 15, 15]

std_dev1 = np.std(dataset1, ddof=1)
std_dev2 = np.std(dataset2, ddof=1)
dataset = ['dataset1','dataset2']
std = [std_dev1, std_dev2]
plt.figure(figsize=(10,6))
sns.barplot(x=dataset , y=std, palette='coolwarm', hue=dataset, edgecolor='red')
plt.xlabel("DataSet")
plt.ylabel("Standard Deviation")
plt.title("Comparison of Standard Deviations")
plt.show()

# %% [markdown]
# 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
mean = 50
std = 10
size = 1000

data = np.random.normal(loc = mean, scale = std, size = size)

range = np.max(data)-np.min(data)

q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)

iqr = q3-q1

print(f"The range is {range} and the IQR is {iqr}.")
# Out:
# The range is 60.64266467746455 and the IQR is 13.228592290126265.

# %% [markdown]
# 27. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
data = [10, 12, 14, 16, 18, 20, 22, 24]

data = np.array(data)
mean = np.mean(data)
std = np.std(data, ddof=1)

normalized_data = (data - mean) / std_dev

plt.figure(figsize=(10, 6))
sns.histplot(data, kde=True, color='blue', edgecolor='black')
plt.title('Original Dataset')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(normalized_data, kde=True, color='orange', edgecolor='black')
plt.title('Z-Score Normalized Dataset')
plt.xlabel('Z-Score')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def cal_skew_kurto(mean,std,size):
  data = np.random.normal(loc=mean, scale=std, size=size)
  skewness = skew(data)
  kurtosis_data = kurtosis(data, fisher=True)
  print(f"Skewness is {skewness} and kurtosis is {kurtosis_data:4f}")
  return skewness, kurtosis
mean = 0
std = 1
size = 1000
cal_skew_kurto(mean,std,size)
# Out:
# Skewness is 0.0694951278326892 and kurtosis is 0.129160
# (np.float64(0.0694951278326892),
#  <function scipy.stats._stats_py.kurtosis(a, axis=0, fisher=True, bias=True, nan_policy='propagate', *, keepdims=False)>)
